# %%
import os 
import pandas
from tqdm import tqdm
import plotly.express as px
from datetime import datetime
import plotly.io as pio
pio.renderers.default = "notebook"

# %%
files = os.listdir("../../daily_visits")
files = [os.path.join(os.getcwd(), "../../daily_visits", file) for file in files]

# %%
visits = pandas.DataFrame()
for f in tqdm(sorted(files)):
    visits = pandas.concat([visits, pandas.read_csv(f)])
visits = visits[visits["location"] == "Planet Fitness"] # Keep only Planet Fitness
visits.reset_index(inplace=True, drop=True)
visits.drop(visits.filter(regex="Unname"),axis=1, inplace=True) # drop the first unnamed column
visits
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 302/302 [00:01<00:00, 255.78it/s]
#            location  year month  day  total_visits  unique_users  dwell_sum  \
# 0    Planet Fitness  2019   dec    1         50039         48184  3027388.0
# 1    Planet Fitness  2019   dec    2         63563         61533  3663538.0
# 2    Planet Fitness  2019   dec    3         74664         71186  4291285.0
# 3    Planet Fitness  2019   dec    4         74605         71196  4326335.0
# 4    Planet Fitness  2019   dec    5         73132         69807  4263392.0
# ..              ...   ...   ...  ...           ...           ...        ...
# 297  Planet Fitness  2020   may   27         29045         27516  1779967.0
# 298  Planet Fitness  2020   may   28         30128         28507  1862604.0
# 299  Planet Fitness  2020   may   29         32577         31066  1886326.0
# 300  Planet Fitness  2020   may   30         29737         28528  1656566.0
# 301  Planet Fitness  2020   may   31         22255         21489  1323243.0
#
#      dwell_mean  dwell_mean_per_user
# 0     60.500570            62.829736
# 1     57.636329            59.537776
# 2     57.474620            60.282710
# 3     57.989880            60.766546
# 4     58.297216            61.073990
# ..          ...                  ...
# 297   61.283078            64.688436
# 298   61.823022            65.338478
# 299   57.903613            60.719951
# 300   55.707233            58.068073
# 301   59.458234            61.577691
#
# [302 rows x 9 columns]

# %%
# convert name of month into number
month_conv = {"jan": 1, "feb": 2, "mar": 3, "apr": 4, "may": 5, "jun": 6, "jul": 7, "aug": 8, "sep": 9,
              "oct": 10, "nov": 11, "dec": 12}
# create the datetime dates
dates = []
for i, r in visits.iterrows():
    date = datetime(visits["year"].iloc[i], month_conv[visits["month"].iloc[i]], visits["day"].iloc[i])
    date = datetime.date(date)
    dates += [date]
visits["date"] = dates
visits
# Out:
#            location  year month  day  total_visits  unique_users  dwell_sum  \
# 0    Planet Fitness  2019   dec    1         50039         48184  3027388.0
# 1    Planet Fitness  2019   dec    2         63563         61533  3663538.0
# 2    Planet Fitness  2019   dec    3         74664         71186  4291285.0
# 3    Planet Fitness  2019   dec    4         74605         71196  4326335.0
# 4    Planet Fitness  2019   dec    5         73132         69807  4263392.0
# ..              ...   ...   ...  ...           ...           ...        ...
# 297  Planet Fitness  2020   may   27         29045         27516  1779967.0
# 298  Planet Fitness  2020   may   28         30128         28507  1862604.0
# 299  Planet Fitness  2020   may   29         32577         31066  1886326.0
# 300  Planet Fitness  2020   may   30         29737         28528  1656566.0
# 301  Planet Fitness  2020   may   31         22255         21489  1323243.0
#
#      dwell_mean  dwell_mean_per_user        date
# 0     60.500570            62.829736  2019-12-01
# 1     57.636329            59.537776  2019-12-02
# 2     57.474620            60.282710  2019-12-03
# 3     57.989880            60.766546  2019-12-04
# 4     58.297216            61.073990  2019-12-05
# ..          ...                  ...         ...
# 297   61.283078            64.688436  2020-05-27
# 298   61.823022            65.338478  2020-05-28
# 299   57.903613            60.719951  2020-05-29
# 300   55.707233            58.068073  2020-05-30
# 301   59.458234            61.577691  2020-05-31
#
# [302 rows x 10 columns]

# %%
# Sort rows by date
visits.sort_values(by = "date", inplace=True)
visits.reset_index(inplace=True, drop=True)
visits
# Out:
#            location  year month  day  total_visits  unique_users  dwell_sum  \
# 0    Planet Fitness  2019   sep    1         46581         44886  2870826.0
# 1    Planet Fitness  2019   sep    2         54301         52597  3222610.0
# 2    Planet Fitness  2019   sep    3         67158         64851  3967443.0
# 3    Planet Fitness  2019   sep    4         77601         74249  4575223.0
# 4    Planet Fitness  2019   sep    5         74714         71457  4414089.0
# ..              ...   ...   ...  ...           ...           ...        ...
# 297  Planet Fitness  2020   jun   24         51511         49062  3127597.0
# 298  Planet Fitness  2020   jun   25         49335         47008  2982897.0
# 299  Planet Fitness  2020   jun   26         47323         45146  2820233.0
# 300  Planet Fitness  2020   jun   27         40526         38794  2378719.0
# 301  Planet Fitness  2020   jun   28         32627         31496  2017189.0
#
#      dwell_mean  dwell_mean_per_user        date
# 0     61.630837            63.958161  2019-09-01
# 1     59.347158            61.269844  2019-09-02
# 2     59.076253            61.177823  2019-09-03
# 3     58.958300            61.619995  2019-09-04
# 4     59.079811            61.772660  2019-09-05
# ..          ...                  ...         ...
# 297   60.717070            63.747850  2020-06-24
# 298   60.462086            63.455093  2020-06-25
# 299   59.595398            62.469167  2020-06-26
# 300   58.696121            61.316673  2020-06-27
# 301   61.825758            64.045879  2020-06-28
#
# [302 rows x 10 columns]

# %%
fig = px.line(visits, x='date', y="total_visits", labels={
                     "total_visits": "planet fitness visits"
                 }, width=800, height=300)
fig.update_layout(xaxis_title=None)
fig.show("svg")

# %%
fig.write_image("PlanetFitnessYearlyVisits.pdf")
