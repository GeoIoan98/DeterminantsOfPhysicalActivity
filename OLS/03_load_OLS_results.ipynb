# %%
import os
import pandas as pd
import statsmodels.api as sm

import matplotlib.pyplot as plt
import numpy as np

# %%
model = sm.load('./metadata/linear_regression/mon-tue-dec.pickle')
print(model.summary().as_latex())
# Out:
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}                                             & Fitness and Recreational Sports Centers & \textbf{  R-squared:         } &      0.039    \\
# \textbf{Model:}                                                     &                   OLS                   & \textbf{  Adj. R-squared:    } &      0.039    \\
# \textbf{Method:}                                                    &              Least Squares              & \textbf{  F-statistic:       } &      9470.    \\
# \textbf{Date:}                                                      &             Thu, 16 Jan 2025            & \textbf{  Prob (F-statistic):} &      0.00     \\
# \textbf{Time:}                                                      &                 09:34:52                & \textbf{  Log-Likelihood:    } & -5.3295e+06   \\
# ...

# %%
model = sm.load('./metadata/linear_regression/wed-thu-dec.pickle')
print(model.summary().as_latex())
# Out:
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}                                             & Fitness and Recreational Sports Centers & \textbf{  R-squared:         } &      0.035    \\
# \textbf{Model:}                                                     &                   OLS                   & \textbf{  Adj. R-squared:    } &      0.035    \\
# \textbf{Method:}                                                    &              Least Squares              & \textbf{  F-statistic:       } &      9257.    \\
# \textbf{Date:}                                                      &             Thu, 16 Jan 2025            & \textbf{  Prob (F-statistic):} &      0.00     \\
# \textbf{Time:}                                                      &                 09:36:27                & \textbf{  Log-Likelihood:    } & -5.6456e+06   \\
# ...

# %%
model = sm.load('./metadata/linear_regression/fri-sat-sun-dec.pickle')
print(model.summary().as_latex())
# Out:
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}                                             & Fitness and Recreational Sports Centers & \textbf{  R-squared:         } &      0.023    \\
# \textbf{Model:}                                                     &                   OLS                   & \textbf{  Adj. R-squared:    } &      0.023    \\
# \textbf{Method:}                                                    &              Least Squares              & \textbf{  F-statistic:       } &      9107.    \\
# \textbf{Date:}                                                      &             Thu, 16 Jan 2025            & \textbf{  Prob (F-statistic):} &      0.00     \\
# \textbf{Time:}                                                      &                 09:36:55                & \textbf{  Log-Likelihood:    } & -7.3927e+06   \\
# ...
